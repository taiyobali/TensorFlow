# %% [markdown]
# The Basic way to showing that how to compute activations of layers by layers in tensorflow.

# %%
import numpy as np 
import tensorflow as tf 
from tensorflow.keras.layers import Dense

# %%
x = np.array([[200.0, 17.0]])
layer_1 = Dense(units=25, activation="sigmoid")
a1 = layer_1(x)

# %%
layer_2 = Dense(units=15, activation="sigmoid")
a2 = layer_2(a1)

# %%
layer_3 = Dense(units=3, activation="sigmoid")
a3 = layer_3(a2)

# %%
layer_4 = Dense(units=1, activation="sigmoid")
a4 = layer_4(a3)

# %%
if a4[0]>=0.5:
    print("output:", 1)
else:
    print("output:", 0)
# Out:
# output: 0

# %%
# Tensor datatype is matrix formated (rows*columns) like (1,1) is a 2D matrix in Tensor
a3
# Out:
# <tf.Tensor: shape=(1, 3), dtype=float32, numpy=array([[0.33737183, 0.700693  , 0.6520841 ]], dtype=float32)>
